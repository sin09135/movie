# %% [markdown]
# # EDA of Netflix Content Engagement

# %%
import pandas as pd
import numpy as np
import re

# 경고 무시
import warnings
warnings.filterwarnings('ignore')

# 시각화 라이브러리
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc("font", family="AppleGothic") #경로 설정
import matplotlib.colors as mcolors


df = pd.read_csv('../data/total_netflix_2023 new.csv')
print(df.shape)
df.head()
# Out:
# (18332, 9)
#                                  Title Available Globally? Release Date  \
# 0            The Night Agent: Season 1                 Yes   2023-03-23
# 1            Ginny & Georgia: Season 2                 Yes   2023-01-05
# 2   The Glory: Season 1 // 더 글로리: 시즌 1                 Yes   2022-12-30
# 3                  Wednesday: Season 1                 Yes   2022-11-23
# 4  Queen Charlotte: A Bridgerton Story                 Yes   2023-05-04
#
#   Hours Viewed Number of Ratings Rating                            Genre  \
# 0    812100000            7696.0    6.0        Biography, Drama, History
# 1    665100000            5216.0    5.7            Comedy, Drama,Romance
# 2    622800000           11869.0    8.4                        ['Short']
# 3    507700000           50077.0    7.4  ['Drama', 'History', 'Romance']
# 4    503000000           45624.0    6.6            ['Comedy', 'Romance']
#
#                                            Key Words  \
# 0  persian empire,empire,5th century b.c.,achaeme...
# 1  producer,three word title,headstrong,arranged ...
# 2  prequel,queen,historical,england,queen charlot...
# 3  christmas,coming out,holidays,lesbian relation...
# 4  telenovela,drug trafficking,cartel,femme fatal...
#
#                                          Description
# 0  The film follows headstrong Ginny who meets Su...
# 1  Betrothed against her will to King George, you...
# 2  A holiday romantic comedy that captures the ra...
# 3  The film follows headstrong Ginny who meets Su...
# 4  While fleeing from dangerous assailants, an as...

# %% [markdown]
# ## 1. Data Proprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18332 entries, 0 to 18331
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                18332 non-null  object
#  1   Available Globally?  18332 non-null  object
#  2   Release Date         18332 non-null  object
#  3   Hours Viewed         18332 non-null  object
#  4   Number of Ratings    18332 non-null  object
#  5   Rating               18332 non-null  object
#  6   Genre                18332 non-null  object
#  7   Key Words            18332 non-null  object
#  8   Description          18332 non-null  object
# dtypes: object(9)
# memory usage: 1.3+ MB

# %% [markdown]
# - 중복 확인

# %%
duplicates = df[df.duplicated()]
display(duplicates)

# 중복 제거
df = df.drop_duplicates()
df.reset_index(drop=True, inplace=True)

print()
df.shape
# Out:
#                                              Title Available Globally?  \
# 18242                                 Wolf // Varg                  No
# 18268  You Are the Apple of My Eye // 那些年，我們一起追的女孩                  No
#
#       Release Date Hours Viewed Number of Ratings Rating Genre Key Words  \
# 18242            0            0                 0      0     0         0
# 18268            0            0                 0      0     0         0
#
#       Description
# 18242           0
# 18268           0
# (18330, 9)

# %% [markdown]
# - 데이터 클리닝 : Genre

# %%
df['Genre'] = df['Genre'].str.replace('[', '').str.replace(']', '').str.replace("'", "")

# %% [markdown]
# - Season 포함 여부에 따라 데이터 비닝

# %%
df['Type'] = df['Title'].str.contains('Season', case=False, na=False).map({True: 'TV Show', False: 'Movie'})

# %% [markdown]
# - 수치형 컬럼 클리닝 후 숫자로 변환

# %%
# errors='coerce'에러가 생길경우 NaN 처리
df['Hours Viewed'] = pd.to_numeric(df['Hours Viewed'].str.replace(',', ''), errors='coerce')
df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')
df['Number of Ratings'] = pd.to_numeric(df['Number of Ratings'].str.replace(',', ''), errors='coerce')

# %%
df['release_date_parsed'] = pd.to_datetime(df['Release Date'], errors='coerce', infer_datetime_format=True)

# %%
df.head()
# Out:
#                                  Title Available Globally? Release Date  \
# 0            The Night Agent: Season 1                 Yes   2023-03-23
# 1            Ginny & Georgia: Season 2                 Yes   2023-01-05
# 2   The Glory: Season 1 // 더 글로리: 시즌 1                 Yes   2022-12-30
# 3                  Wednesday: Season 1                 Yes   2022-11-23
# 4  Queen Charlotte: A Bridgerton Story                 Yes   2023-05-04
#
#    Hours Viewed  Number of Ratings  Rating                      Genre  \
# 0     812100000               7696       6  Biography, Drama, History
# 1     665100000               5216       6      Comedy, Drama,Romance
# 2     622800000              11869       8                      Short
# 3     507700000              50077       7    Drama, History, Romance
# 4     503000000              45624       7            Comedy, Romance
#
#                                            Key Words  \
# 0  persian empire,empire,5th century b.c.,achaeme...
# 1  producer,three word title,headstrong,arranged ...
# 2  prequel,queen,historical,england,queen charlot...
# 3  christmas,coming out,holidays,lesbian relation...
# 4  telenovela,drug trafficking,cartel,femme fatal...
#
#                                          Description     Type  \
# 0  The film follows headstrong Ginny who meets Su...  TV Show
# 1  Betrothed against her will to King George, you...  TV Show
# 2  A holiday romantic comedy that captures the ra...  TV Show
# 3  The film follows headstrong Ginny who meets Su...  TV Show
# 4  While fleeing from dangerous assailants, an as...    Movie
#
#   release_date_parsed
# 0          2023-03-23
# 1          2023-01-05
# 2          2022-12-30
# 3          2022-11-23
# 4          2023-05-04

# %%
# 한국어 포함 여부를 판단하는 함수
def contains_korean(text):
    return 1 if re.search('[가-힣]', text) else 0

# Korea 컬럼 생성
df['Korea'] = df['Title'].apply(contains_korean)

# %%
df['Korea'].value_counts()
# Out:
# 0    17192
# 1     1138
# Name: Korea, dtype: int64

# %% [markdown]
# ## 2. EDA

# %% [markdown]
# ### 2.0. Type of Contents

# %%
# Type별로 Hoursviewed 합계를 구함
pd.options.display.float_format = '{:.0f}'.format

df_sum_type = df.groupby('Type')['Hours Viewed'].sum().reset_index()
df_sum_type
# Out:
#       Type  Hours Viewed
# 0    Movie   87253400000
# 1  TV Show   73470400000

# %%
df_korea = df[df['Korea'] == 1]
df_K_sum_type = df_korea.groupby('Type')['Hours Viewed'].sum().reset_index()
df_K_sum_type
# Out:
#       Type  Hours Viewed
# 0    Movie    5147300000
# 1  TV Show    4889000000

# %%
df_count_type = df.groupby('Type')['Hours Viewed'].count().reset_index()
df_count_type
# Out:
#       Type  Hours Viewed
# 0    Movie         12447
# 1  TV Show          5881

# %%
df_k_count_type = df_korea.groupby('Type')['Hours Viewed'].count().reset_index()
df_k_count_type
# Out:
#       Type  Hours Viewed
# 0    Movie           718
# 1  TV Show           420

# %% [markdown]
# ### 2.1. Cumulative Hours Watched Yearly

# %%
df_clean = df.dropna(subset=['release_date_parsed']) # Nat 제거

# year 추출
df_clean['release_year'] = df_clean['release_date_parsed'].dt.year

# Group by
yearly_hours = df_clean.groupby('release_year')['Hours Viewed'].sum()

# Calculate
cumulative_hours = yearly_hours.cumsum()

# Plotting
cumulative_hours.plot(kind='line', title='Cumulative Hours Watched Yearly', color='red')
plt.xlabel('Year')
plt.ylabel('Cumulative Hours Watched')
plt.show()

# %%
cumulative_hours
# Out:
# release_year
# 2010      207300000
# 2011      528300000
# 2012      538800000
# 2013      957300000
# 2014     1712100000
# 2015     3558300000
# 2016     7337100000
# 2017    14271000000
# 2018    22590000000
# 2019    33767100000
# 2020    49038600000
# 2021    68721300000
# 2022   108753900000
# 2023   160723800000
# Name: Hours Viewed, dtype: float64

# %% [markdown]
# ### 2.2. Group by Genre

# %%
df.head()
# Out:
#                                  Title Available Globally? Release Date  \
# 0            The Night Agent: Season 1                 Yes   2023-03-23
# 1            Ginny & Georgia: Season 2                 Yes   2023-01-05
# 2   The Glory: Season 1 // 더 글로리: 시즌 1                 Yes   2022-12-30
# 3                  Wednesday: Season 1                 Yes   2022-11-23
# 4  Queen Charlotte: A Bridgerton Story                 Yes   2023-05-04
#
#    Hours Viewed  Number of Ratings  Rating                      Genre  \
# 0   812100000.0             7696.0     6.0  Biography, Drama, History
# 1   665100000.0             5216.0     5.7      Comedy, Drama,Romance
# 2   622800000.0            11869.0     8.4                      Short
# 3   507700000.0            50077.0     7.4    Drama, History, Romance
# 4   503000000.0            45624.0     6.6            Comedy, Romance
#
#                                            Key Words  \
# 0  persian empire,empire,5th century b.c.,achaeme...
# 1  producer,three word title,headstrong,arranged ...
# 2  prequel,queen,historical,england,queen charlot...
# 3  christmas,coming out,holidays,lesbian relation...
# 4  telenovela,drug trafficking,cartel,femme fatal...
#
#                                          Description     Type  \
# 0  The film follows headstrong Ginny who meets Su...  TV Show
# 1  Betrothed against her will to King George, you...  TV Show
# 2  A holiday romantic comedy that captures the ra...  TV Show
# 3  The film follows headstrong Ginny who meets Su...  TV Show
# 4  While fleeing from dangerous assailants, an as...    Movie
#
#   release_date_parsed
# 0          2023-03-23
# 1          2023-01-05
# 2          2022-12-30
# 3          2022-11-23
# 4          2023-05-04

# %%
df['Genre'] = df['Genre'].replace('0', np.nan)
df['Genre'] = df['Genre'].dropna().astype(str).str.split(',')
print(df['Genre'].head())
# Out:
# 0    [Biography,  Drama,  History]
# 1        [Comedy,  Drama, Romance]
# 2                          [Short]
# 3      [Drama,  History,  Romance]
# 4               [Comedy,  Romance]
# Name: Genre, dtype: object

# %%
# Group by Genre
df_exploded = df.explode('Genre')
genre_stats = df_exploded.groupby('Genre').agg({'Rating': 'mean', 'Hours Viewed': 'mean', 'Number of Ratings': 'sum'})

# colormap 
cmap = plt.get_cmap('Reds')
bright_cmap = mcolors.LinearSegmentedColormap.from_list('bright_cmap', cmap(np.linspace(0.5, 1, 256)))

# Plotting
axes = genre_stats.plot(kind='bar', subplots=True, layout=(4, 1), figsize=(10, 15), sharex=False, cmap=bright_cmap)

# subplots
axes[0][0].set_title('Average Rating by Genre')
axes[0][0].set_xlabel('Genre')
axes[0][0].set_ylabel('Average Rating')

axes[1][0].set_title('Average Hours Viewed by Genre')
axes[1][0].set_xlabel('Genre')
axes[1][0].set_ylabel('Average Hours Viewed')

axes[2][0].set_title('Total Number of Ratings by Genre')
axes[2][0].set_xlabel('Genre')
axes[2][0].set_ylabel('Total Number of Ratings')


plt.tight_layout()

# Display the plot
plt.show()

# %%
def plot_genre_stats(df, colormap_ratings='Blues', colormap_hours='Greens', colormap_ratings_count='Reds'):
    # Group by Genre
    df_exploded = df.explode('Genre')
    genre_stats = df_exploded.groupby('Genre').agg({'Rating': 'mean', 'Hours Viewed': 'mean', 'Number of Ratings': 'sum'})

    # Sort by average rating
    genre_stats = genre_stats.sort_values(by='Rating', ascending=False)

    # Colormaps
    cmap_ratings = plt.get_cmap(colormap_ratings)
    bright_cmap_ratings = mcolors.LinearSegmentedColormap.from_list('bright_cmap_ratings', cmap_ratings(np.linspace(0.5, 1, 256)))

    cmap_hours = plt.get_cmap(colormap_hours)
    bright_cmap_hours = mcolors.LinearSegmentedColormap.from_list('bright_cmap_hours', cmap_hours(np.linspace(0.5, 1, 256)))

    cmap_ratings_count = plt.get_cmap(colormap_ratings_count)
    bright_cmap_ratings_count = mcolors.LinearSegmentedColormap.from_list('bright_cmap_ratings_count', cmap_ratings_count(np.linspace(0.5, 1, 256)))

    # Plotting
    fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 15), sharex=False)

    # Plotting each subplot with different colormaps
    genre_stats['Rating'].plot(kind='bar', ax=axes[0], color=bright_cmap_ratings(np.linspace(0.5, 1, len(genre_stats))), edgecolor='black')
    genre_stats['Hours Viewed'].plot(kind='bar', ax=axes[1], color=bright_cmap_hours(np.linspace(0.5, 1, len(genre_stats))), edgecolor='black')
    genre_stats['Number of Ratings'].plot(kind='bar', ax=axes[2], color=bright_cmap_ratings_count(np.linspace(0.5, 1, len(genre_stats))), edgecolor='black')

    # Setting titles and labels
    axes[0].set_title('Average Rating by Genre')
    axes[0].set_ylabel('Average Rating')

    axes[1].set_title('Average Hours Viewed by Genre')
    axes[1].set_ylabel('Average Hours Viewed')

    axes[2].set_title('Total Number of Ratings by Genre')
    axes[2].set_xlabel('Genre')
    axes[2].set_ylabel('Total Number of Ratings')

    # Tight layout
    plt.tight_layout()

    # Display the plot
    plt.show()

# %%
plot_genre_stats(df, colormap_ratings='Blues', colormap_hours='Greens', colormap_ratings_count='Reds')

# %% [markdown]
# #### 2.2.1. Movie

# %%
# 필터링
df_filtered = df[df['Type'] == 'Movie']
plot_genre_stats(df_filtered, colormap_ratings='Blues', colormap_hours='Greens', colormap_ratings_count='Reds')

# %% [markdown]
# #### 2.2.2. TV Show

# %%
# 필터링
df_filtered = df[df['Type'] == 'TV Show']
plot_genre_stats(df_filtered, colormap_ratings='Blues', colormap_hours='Greens', colormap_ratings_count='Reds')

# %% [markdown]
# ### 2.3. Correlation

# %%
# Convert 'Available Globally?' to a binary numeric column 
df_exploded['Available Globally?'] = df_exploded['Available Globally?'].map({'Yes': 1, 'No': 0})

# Group by 'Genre' and calculate the sum of 'hours viewed' and the mean of 'Available Globally?'
genre_popularity = df_exploded.groupby('Genre').agg({'Hours Viewed': 'sum', 'Available Globally?': 'mean'})

# Now calculate the correlation
correlation = genre_popularity.corr()

# Display the correlation matrix
display(correlation)
# Out:
#                      Hours Viewed  Available Globally?
# Hours Viewed             1.000000             0.195908
# Available Globally?      0.195908             1.000000

# %%
def calculate_genre_correlation(df, group_column, value_column1, value_column2):
    """
    Calculate correlation between two columns within each group defined by another column.
    
    Parameters:
        df (DataFrame): DataFrame containing the data.
        group_column (str): Name of the column used to group the data.
        value_column1 (str): Name of the first column used for correlation calculation.
        value_column2 (str): Name of the second column used for correlation calculation.
    
    Returns:
        Series: Series containing correlation values for each group.
    """
    grouped = df.groupby(group_column)
    
    def calculate_correlation(group):
        return group[value_column1].corr(group[value_column2])
    
    genre_correlation = grouped.apply(calculate_correlation)
    
    return genre_correlation

# Usage example
genre_correlation = calculate_genre_correlation(df_exploded, 'Genre', 'Hours Viewed', 'Available Globally?')

# %%
# Group the data by 'Genre'
grouped = df_exploded.groupby('Genre')

# Define a function to calculate the correlation for each group
def calculate_correlation(group):
    return group['Hours Viewed'].corr(group['Available Globally?'])

# Apply the function to each genre group
genre_correlation = grouped.apply(calculate_correlation)

# %%
genre_correlation
# Out:
# Genre
#  Action         0.098452
#  Adventure      0.075043
#  Animation      0.086605
#  Biography      0.090897
#  Comedy         0.051148
#  Crime          0.132311
#  Documentary    0.025435
#  Drama          0.131184
#  Family         0.170196
#  Fantasy        0.122070
#  Game-Show      0.720571
#  History        0.134278
#  Horror         0.120997
#  Music          0.139752
#  Musical        0.129126
#  Mystery        0.167260
#  News          -0.078429
#  Reality-TV     0.115812
#  Romance        0.159914
#  Sci-Fi         0.200307
#  Short          0.045166
#  Sport          0.146316
#  Talk-Show      0.182074
#  Thriller       0.101192
#  War            0.223612
#  Western        0.235565
# Action          0.150314
# Adventure       0.262827
# Animation       0.034855
# Biography       0.109694
# Comedy          0.102299
# Crime           0.173185
# Documentary     0.096476
# Drama           0.067571
# Family          0.194944
# Fantasy         0.023860
# Game-Show       0.238250
# Genre                NaN
# History        -0.014690
# Horror          0.200504
# Music           0.091927
# Musical         0.169871
# Mystery         0.095315
# Reality-TV     -0.048322
# Romance         0.303031
# Sci-Fi          0.519211
# Short           0.122762
# Sport           0.271221
# Talk-Show       0.060045
# Thriller        0.489827
# Western        -0.015153
# dtype: float64

# %%
# 새로운 figure와 axis 생성
fig, ax = plt.subplots(figsize=(10, 6))

# 상관 관계를 시각화
genre_correlation.sort_values(ascending=False).plot(kind='bar', color='skyblue', ax=ax)

# 그래프 타이틀과 레이블 설정
ax.set_title('Correlation between Hours Viewed and Available Globally by Genre')
ax.set_xlabel('Genre')
ax.set_ylabel('Correlation')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
ax.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# 그래프 표시
plt.show()

# %%
# Set up a FacetGrid to plot multiple genres
g = sns.FacetGrid(df_exploded, col='Genre', col_wrap=4, height=4, aspect=1)

#FacetGrid
g.map(sns.regplot, 'Available Globally?', 'Hours Viewed', color='red')

# Set up titles
g.set_titles("{col_name}")

# Show the plots
plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18330 entries, 0 to 18329
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                18330 non-null  object
#  1   Available Globally?  18330 non-null  object
#  2   Release Date         18330 non-null  object
#  3   Hours Viewed         18328 non-null  float64
#  4   Number of Ratings    18326 non-null  float64
#  5   Rating               18326 non-null  float64
#  6   Genre                17909 non-null  object
#  7   Key Words            18330 non-null  object
#  8   Description          18330 non-null  object
#  9   Type                 18330 non-null  object
#  10  release_date_parsed  14637 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), object(7)
# memory usage: 1.5+ MB

# %% [markdown]
# ### 2.4 Ranked Data

# %%
def rank_hours_viewed_by_year_quarter(data):
    # "Release Date" 열에서 연도 및 분기 정보를 추출
    data['Year'] = data['release_date_parsed'].dt.year
    data['Quarter'] = data['release_date_parsed'].dt.quarter
    
    # 연도/분기 별로 같은 컨텐츠들 중 "Hours Viewed"에 따른 순위 계산
    ranked_data = data.groupby(['Year', 'Quarter', 'Title'])['Hours Viewed'].sum().reset_index()
    ranked_data['Rank'] = ranked_data.groupby(['Year', 'Quarter'])['Hours Viewed'].rank(ascending=False, method='dense')
    
    return ranked_data
ranked_data = rank_hours_viewed_by_year_quarter(df)

# %%
ranked_data
# Out:
#          Year  Quarter                                              Title  \
# 0      2010.0      2.0                           Chi mon chaton: Season 1
# 1      2010.0      2.0                                      Damage (1992)
# 2      2010.0      2.0                           Grey's Anatomy: Season 4
# 3      2010.0      2.0  Guardian: The Lonely and Great God: Season 1 /...
# 4      2010.0      2.0                            Lost in Space: Season 3
# ...       ...      ...                                                ...
# 14629  2023.0      2.0  Yu Yu Hakusho: Ghost Files: Season 1 // 幽☆遊☆白書...
# 14630  2023.0      2.0                              ¡Asu Mare! Los amigos
# 14631  2023.0      2.0                                   İllegal Hayatlar
# 14632  2023.0      2.0            【OSHI NO KO】: Season 1 // 【推しの子】: シーズン1
# 14633  2023.0      2.0                           달의 연인 - 보보경심 려: Season 1
#
#        Hours Viewed   Rank
# 0        17600000.0    1.0
# 1        11300000.0    2.0
# 2        17600000.0    1.0
# 3        11300000.0    2.0
# 4         7000000.0    3.0
# ...             ...    ...
# 14629     5200000.0  124.0
# 14630    35200000.0   55.0
# 14631   194700000.0    9.0
# 14632    11800000.0   99.0
# 14633    18600000.0   83.0
#
# [14634 rows x 5 columns]

# %%
df_sorted = ranked_data.sort_values(by=['Year', 'Quarter'], ascending=False)

# %% [markdown]
# ## 3. EDA_Korea

# %%
df_korea_sorted = df_korea.sort_values(by=['Rating','Hours Viewed'],ascending=False)
df_korea_sorted
# Out:
#                                              Title Available Globally?  \
# 1947                  Hwarang: Season 1 // 화랑: 시즌1                  No
# 16315    Love After Divorce: Season 2 // 돌싱글즈: 시즌2                  No
# 13064                               FENGSHUI // 명당                  No
# 9324                          The Roundup // 범죄도시2                  No
# 2348                 Signal: Season 1 // 시그널: 시즌 1                  No
# ...                                            ...                 ...
# 18259  Yellow Muzi & Friends: Season 1 // 내 마음은 무지                  No
# 18277              Young Adult Matters // 어른들은 몰라요                  No
# 18327                                    두근두근 내 인생                  No
# 18328                                       라디오 스타                  No
# 18329                                       선생 김봉두                  No
#
#       Release Date  Hours Viewed  Number of Ratings  Rating  \
# 1947    2020-06-05       4600000                 12      10
# 16315            0             0                 12      10
# 13064   2017-09-22       1200000                  5       9
# 9324    2019-01-25        200000                  8       9
# 2348    2018-09-24       3100000                237       9
# ...            ...           ...                ...     ...
# 18259            0             0                  0       0
# 18277            0             0                  0       0
# 18327            0             0                  0       0
# 18328            0             0                  0       0
# 18329            0             0                  0       0
#
#                            Genre  \
# 1947                 Documentary
# 16315          Drama, Reality-TV
# 13064     Comedy, Drama, Romance
# 9324         Documentary, Comedy
# 2348   Action, Adventure, Comedy
# ...                          ...
# 18259                          0
# 18277                          0
# 18327                          0
# 18328                          0
# 18329                          0
#
#                                                Key Words  \
# 1947     panties,teenager,friendship,party,female nudity
# 16315                                                  0
# 13064  live action remake of anime,based on manga,gam...
# 9324   lawyer,spin off,psychosomatic illness,criminal...
# 2348   drug abuse,narcotic abuse,overdose,prostitutio...
# ...                                                  ...
# 18259                                                  0
# 18277                                                  0
# 18327                                                  0
# 18328                                                  0
# 18329                                                  0
#
#                                              Description     Type  \
# 1947   Tells the true and untold story of prolific ra...  TV Show
# 16315  A girl in search of her true reflection in a d...  TV Show
# 13064  After their van breaks down in the middle of n...    Movie
# 9324   Drea and Eleanor agree to go after one another...    Movie
# 2348   Follows the tragedy in which terrorists detona...  TV Show
# ...                                                  ...      ...
# 18259                                                  0  TV Show
# 18277                                                  0    Movie
# 18327                                                  0    Movie
# 18328                                                  0    Movie
# 18329                                                  0    Movie
#
#       release_date_parsed  Korea
# 1947           2020-06-05      1
# 16315                 NaT      1
# 13064          2017-09-22      1
# 9324           2019-01-25      1
# 2348           2018-09-24      1
# ...                   ...    ...
# 18259                 NaT      1
# 18277                 NaT      1
# 18327                 NaT      1
# 18328                 NaT      1
# 18329                 NaT      1
#
# [1138 rows x 12 columns]

# %% [markdown]
# ### 3.1. 기존 분류 원칙 대로 분류

# %%
df_korea_movie = df_korea[df_korea['Type']=='Movie'].sort_values(by=['Rating','Hours Viewed'],ascending=False)

# %%
df_korea_movie
# Out:
#                                                    Title Available Globally?  \
# 13064                                     FENGSHUI // 명당                  No
# 9324                                The Roundup // 범죄도시2                  No
# 14600                             A Werewolf Boy // 늑대소년                  No
# 15771  Hello Jadoo Special : Journey to west // 안녕 자두...                  No
# 10644  Ask Us Anything Fortune Teller: 2021-2022 // 무...                  No
# ...                                                  ...                 ...
# 18252                                    Wretches // 괴물들                  No
# 18277                    Young Adult Matters // 어른들은 몰라요                  No
# 18327                                          두근두근 내 인생                  No
# 18328                                             라디오 스타                  No
# 18329                                             선생 김봉두                  No
#
#       Release Date  Hours Viewed  Number of Ratings  Rating  \
# 13064   2017-09-22       1200000                  5       9
# 9324    2019-01-25        200000                  8       9
# 14600   2021-12-16        100000                237       9
# 15771            0             0                237       9
# 10644   2021-04-29      13000000              14592       9
# ...            ...           ...                ...     ...
# 18252            0             0                  0       0
# 18277            0             0                  0       0
# 18327            0             0                  0       0
# 18328            0             0                  0       0
# 18329            0             0                  0       0
#
#                           Genre  \
# 13064    Comedy, Drama, Romance
# 9324        Documentary, Comedy
# 14600  Action, Adventure, Drama
# 15771          Animation, Short
# 10644               Documentary
# ...                         ...
# 18252                         0
# 18277                         0
# 18327                         0
# 18328                         0
# 18329                         0
#
#                                                Key Words  \
# 13064  live action remake of anime,based on manga,gam...
# 9324   lawyer,spin off,psychosomatic illness,criminal...
# 14600    cabinet,girl,politics,husband wife relationship
# 15771                                                  0
# 10644                     store,game,money,lawyer,secret
# ...                                                  ...
# 18252                                                  0
# 18277                                                  0
# 18327                                                  0
# 18328                                                  0
# 18329                                                  0
#
#                                              Description   Type  \
# 13064  After their van breaks down in the middle of n...  Movie
# 9324   Drea and Eleanor agree to go after one another...  Movie
# 14600  Economical advisers give out their tips on how...  Movie
# 15771  What is the formula for happiness? Alessandro ...  Movie
# 10644  After his arrest at age 16, Kalief Browder fou...  Movie
# ...                                                  ...    ...
# 18252                                                  0  Movie
# 18277                                                  0  Movie
# 18327                                                  0  Movie
# 18328                                                  0  Movie
# 18329                                                  0  Movie
#
#       release_date_parsed  Korea
# 13064          2017-09-22      1
# 9324           2019-01-25      1
# 14600          2021-12-16      1
# 15771                 NaT      1
# 10644          2021-04-29      1
# ...                   ...    ...
# 18252                 NaT      1
# 18277                 NaT      1
# 18327                 NaT      1
# 18328                 NaT      1
# 18329                 NaT      1
#
# [718 rows x 12 columns]

# %%
# '//' 뒤에 있는 단어 추출하는 함수
def extract_after_slash(text):
    return [item.split('//')[1].strip() if '//' in item else 'Not Available' for item in text]


# 각 문자열에서 '//' 뒤에 있는 단어 추출하여 리스트에 추가
df_korea_movie['Title_Korea'] = extract_after_slash(df_korea_movie['Title'])

# %%
df_korea_movie['Available Globally?'].value_counts()
# Out:
# No     640
# Yes     78
# Name: Available Globally?, dtype: int64

# %%
df_korea_movie_global = df_korea_movie[df_korea_movie['Available Globally?'] == 'Yes']
df_korea_movie_n = df_korea_movie[df_korea_movie['Available Globally?'] == 'No']

# %%
k_movie_global = df_korea_movie_global['Title_Korea'].tolist()

# %%
k_movie_n = df_korea_movie_n['Title_Korea'].tolist()

# %%
print(k_movie_global)
# Out:
# ['길복순', '핑크퐁 시네마 콘서트: 우주대탐험', '낙원의 밤', '기억의 밤', '마녀체력 농구부: 2022', '신성한, 이혼: 리미티드 시리즈', '20세기 소녀', '슈룹: 리미티드 시리즈', '강철비', '연애의 참견: 2021', '염력', '일타 스캔들: 리미티드 시리즈', '나쁜엄마: 리미티드 시리즈', '아는 형님: 2020', '아는 형님: 2023', '셀러브리티: 리미티드 시리즈', '해적: 도깨비 깃발', '런닝맨', '글리치: 리미티드 시리즈', '사랑의 이해: 리미티드 시리즈', '안나라수마나라: 리미티드 시리즈', '서울대작전', '환혼: 파트 1', '위시유', '뭉쳐야 찬다: 2023', '이번 생도 잘 부탁해: 리미티드 시리즈', '페르소나: 컬렉션', '미씽: 그들이 있었다', '로보카폴리 안전시리즈', '사바하', '블랙독', '레인코트 킬러: 유영철을 추격하다: 리미티드 시리즈', '보이스 2', '어쩌다 전원일기: 리미티드 시리즈', '뭉쳐야 찬다: 2021-2022', '캐치! 티니핑', '또봇V <갤럭시웨폰 4호의 비밀>', '스마트폰을 떨어뜨렸을 뿐인데', '새콤달콤', '왕이 된 남자', '사냥의 시간', '유열의 음악앨범', '킹덤: 아신전', '악질경찰', '으라차차 와이키키', '상류사회', '진심이 닿다', '킹 오브 클론 : 황우석 박사의 몰락', '야차', '제8일의 밤', '트롤리: 리미티드 시리즈', '1호가 될 순 없어: 2021', '닥터 차정숙: 리미티드 시리즈', '스마트폰을 떨어뜨렸을 뿐인데', '정이', '마약왕', '미생', '캐치! 티니핑: 반짝반짝 캐치! 티니핑', '아는 형님: 2022', '최강야구: Part 1', '아는 형님: 2021', '사이버 지옥: n번방을 무너뜨려라', '환혼: 파트 2', '무법변호사', '최강야구: Part 2', '도시괴담: 컬렉션', '#살아있다', '카터', '모럴센스', '리벤져', '나 홀로 그대: 리미티드 시리즈', '콜', '승리호', 'Not Available', '멜로가 체질', '연예인 매니저로 살아남기: 리미티드 시리즈', '인랑', '차인표']

# %%
print(k_movie_n)
# Out:
# ['명당', '범죄도시2', '늑대소년', '안녕 자두야 서유기 : 어쩌다 영웅', '무엇이든 물어보살: 2021-2022', '전우치', '사자', '알 포인트', '왜그래 풍상씨', '바르게 살자', 'Not Available', '친절한 금자씨', '용루각: 비정도시', '경관의 피', '황금빛 내 인생', '감쪽같은 그녀', '형', '아빠는 딸', '엽기적인 그녀', '차이나타운', '해피엔드', '철인왕후', '연애 빠진 로맨스', '마더', '전설의 주먹', '홈타운', '해피니스', '초면에 사랑합니다', '이상한 나라의 수학자', '죽지않는 인간들의 밤', '임금님의 사건수첩', '제인의 썸머', '인생은 아름다워', '쫑알쫑알 똘똘이 3', '도희야', '클래식', '사생결단', '좋은 친구들', '귀문', '헬로카봇 10', '악마를 보았다', '탐정: 리턴즈', '편의점 샛별이', '고고다이노 공룡탐험대 2', '시월애', '오은영의 금쪽상담소: 2023', '배드 앤 크레이지', '악인전', '악녀', '비정규직 특수요원', '고백부부', '안녕자두야 3', '수상한 그녀', '집으로 가는 길', '바람난가족', '조선명탐정: 각시투구꽃의 비밀', '파이란', '침입자', '왕의 남자', '다이노 어드벤처 육해공 킬러 엘리트', '불도저에 탄 소녀', '우아한 거짓말', '마녀의 법정', '증인', '신과함께-죄와 벌', '싱크홀', '목격자', '혼숨', '가문의 영광', '비밀은 없다', '크리스마스 캐럴', '스파이', '넌 내게 반했어', '희생부활자', '자백', '무수단', '노브레싱', '국가대표2', '해치지않아', '요가학원: 죽음의 쿤달리니', '방자전', '궁합', '이미테이션', '카운트', '시', '해무', '실미도', '부라더', '작은 아씨들: 리미티드 시리즈', '언니', '지금 만나러 갑니다', '쫑알쫑알 똘똘이 1', '결혼은, 미친짓이다', '마담 뺑덕', '맛있는 녀석들: 시즌 2021', '변신', '가루지기', '열한번째 엄마', '아웃도어 비긴즈', '우아한 세계', '곡성', '신과함께-인과 연', '오늘의 연애', '내가 살인범이다', '올레', '검사내전', '건축탐구 - 집: 2022', '미옥', '외출', '금쪽같은 내새끼: 2021', '뽕숭아학당: 2021', '살인의뢰', '화려한 휴가', '범죄와의 전쟁: 나쁜놈들 전성시대', '너의 결혼식', '무뢰한', '루시드 드림', '성난황소', '블랙머니', '해피뻐스데이', '보통사람', '타짜: 원 아이드 잭', '간신', '언니', '맛있는 녀석들: 시즌 2018-2019', '명량', '스위치', '히든', '미쓰 와이프', '2020 트롯 어워즈', '굿바이 싱글', '복수는 나의 것', '자산어보', '다시 뜨거워지고 싶은 애로부부: 2021', '아무것도 하고 싶지 않아', '옆집사람', '이끼', '무엇이든 물어보살: 2023', '방법: 재차의', '미씽: 그들이 있었다 2', '미션 파서블', '신청곡을 불러드립니다 - 사랑의 콜센타: 2020', '숨바꼭질', '연애의 목적', '지구를 지켜라!', '동네사람들', '나쁜 녀석들: 더 무비', '국제시장', '공공의 적 2', '지푸라기라도 잡고 싶은 짐승들', '여타짜', '앵커', '고스트 닥터', '해바라기', '내안의 그놈', '수상한 고객들', '쎄시봉', '어린 의뢰인', '생활의 발견', '오싹한 연애', '시간이탈자', '오케이 광자매', '출사표', '브로커', '토요일은 밥이 좋아: 2023 파트 1', '늑대사냥', '글러브', '불한당: 나쁜 놈들의 세상', '장르만 로맨스', '7년의 밤', '나의 PS 파트너', '혼자 사는 사람들', '강남 1970', '파파로티', '뽕숭아학당: 2020', '퇴마: 무녀굴', '특별시민', '구미호뎐', '방법', '조작된 도시', '고고다이노 공룡탐험대 3', '악마판사', '영웅', '암살', '올드보이', '그놈이 그놈이다', '산후조리원', 'B컷', '감기', '한공주', '정직한 후보', '독전: 익스텐디드 컷', '집으로 가는 길', '조선명탐정: 흡혈괴마의 비밀', '인디안 썸머', '마파도2', '퀵', '영화는 영화다', '극비수사', '장산범', '폰', '경마장 가는 길', '내일의 기억', '괴물', '금쪽같은 내새끼: 2022', '검색어를 입력하세요 WWW', '연애의 참견: 2023', '사라진 시간', '아수라', '도어락', '어서와~ 한국은 처음이지?', '아이', '꿈의 제인', '물괴', '건축탐구 - 집: 2021', '올빼미', '돌아온다', '사도', '어느 날 우리 집 현관으로 멸망이 들어왔다', '써니', '클로젯', '어사와조이', '교섭', '피끓는 청춘', '스위치', '외계+인 1부', '신세계', '악의 연대기', '고지전', '(아는 건 별로 없지만) 가족입니다', '끝까지 간다', '박쥐', 'Not Available', '아내가 결혼했다', '재심', '작전', '용의자', '마녀', '신사와 아가씨', '강릉', '옥탑방 왕세자', '미스 푸줏간', '진짜가 나타났다!', '스물', '미인도', '남자친구', '해운대', '건축학개론', '보라! 데보라', '맛있는 녀석들: 시즌 2020', '최강전사 미니특공대 : 영웅의 탄생', '미스터 주: 사라진 VIP', '오케이 마담', '내부자들', '호랑이보다 무서운 겨울손님', '어서와~ 한국은 처음이지?: 2022', '로또쉐어', '어부바', '변산', '범죄의 재구성', '더 테러 라이브', '판도라', '캐치! 티니핑: 알쏭달쏭 캐치! 티니핑', '나는 솔로: 5기-8기', '더 킹', '나를 기억해', '어쩌면 우린 헤어졌는지 모른다', '미혹', '덕혜옹주', '해적: 바다로 간 산적', '광해, 왕이 된 남자', '새해전야', 'Not Available', '파수꾼', '용루각2: 신들의 밤', '신라의 달밤', '남매의 여름밤', '공작', '성난 변호사', '화차', '영웅', '용서는 없다', '옆집사람', '공조2: 인터내셔날', '청년경찰', '담보', '내 여자친구는 구미호', '1호가 될 순 없어: 2020', '곤지암', '발신제한', '청춘', '공공의 적', '인간중독', '살인의뢰', '장화, 홍련', '죄 많은 소녀', '분노의 윤리학', '8월의 크리스마스', '황제를 위하여', '나도 아내가 있었으면 좋겠다', '번개맨과 신비의 섬', '미스터 보스', '조폭 마누라 3', '말죽거리 잔혹사', '용의자X', '가문의영광5 - 가문의 귀환', '유체이탈자', '역린', '킹더랜드: 리미티드 시리즈', '더 킬러: 죽어도 되는 아이', '반드시 잡는다', '도굴', '다만 악에서 구하소서', '공조', '7급 공무원', '추억의 검정고무신', '쫑알쫑알 똘똘이 2', '연애의 참견: 2022', '비열한 거리', '밀애', '방황하는 칼날', '좀비탐정', '방구석 1열: 2021', '안녕자두야 4 : 자두와 친구들', '역모 - 반란의 시대', '인질', '광복절 특사', '하이힐', '아는 형님: 2019', '박화영', '뷰티 인사이드', '좋은 놈, 나쁜 놈, 이상한 놈', '고산자, 대동여지도', '검은 사제들\u200b', '정승필 실종사건', 'PMC: 더 벙커', '남자가 사랑할 때', '인사이더', '나는 솔로: 1기-4기', '우리들의 일기', '마음의소리 1', '남과 여', '프리즌', '무엇이든 물어보살: 2022.11-', '고령화 가족', '군도: 민란의 시대', '탐정 홍길동: 사라진 마을', '런닝맨2', '연애의 참견: 2019/2020', '기방도령', '미쓰백', '미씽: 사라진 여자', '모비딕', '특종: 량첸살인기', '밥정', '마지막 늑대', '사장님을 잠금해제', '동네사람들', '대무가', '선배, 그 립스틱 바르지 마요', '살인자의 기억법', '리얼', '극장판 검정고무신: 즐거운 나의 집', '리틀 포레스트', '건축탐구 - 집: 2023', '등산의 목적', '내 ...

# %% [markdown]
# ### 3.2. 새로운 규칙대로 분류

# %%
df_korea_sorted
# Out:
#                                              Title Available Globally?  \
# 1947                  Hwarang: Season 1 // 화랑: 시즌1                  No
# 16315    Love After Divorce: Season 2 // 돌싱글즈: 시즌2                  No
# 13064                               FENGSHUI // 명당                  No
# 9324                          The Roundup // 범죄도시2                  No
# 2348                 Signal: Season 1 // 시그널: 시즌 1                  No
# ...                                            ...                 ...
# 18259  Yellow Muzi & Friends: Season 1 // 내 마음은 무지                  No
# 18277              Young Adult Matters // 어른들은 몰라요                  No
# 18327                                    두근두근 내 인생                  No
# 18328                                       라디오 스타                  No
# 18329                                       선생 김봉두                  No
#
#       Release Date  Hours Viewed  Number of Ratings  Rating  \
# 1947    2020-06-05       4600000                 12      10
# 16315            0             0                 12      10
# 13064   2017-09-22       1200000                  5       9
# 9324    2019-01-25        200000                  8       9
# 2348    2018-09-24       3100000                237       9
# ...            ...           ...                ...     ...
# 18259            0             0                  0       0
# 18277            0             0                  0       0
# 18327            0             0                  0       0
# 18328            0             0                  0       0
# 18329            0             0                  0       0
#
#                            Genre  \
# 1947                 Documentary
# 16315          Drama, Reality-TV
# 13064     Comedy, Drama, Romance
# 9324         Documentary, Comedy
# 2348   Action, Adventure, Comedy
# ...                          ...
# 18259                          0
# 18277                          0
# 18327                          0
# 18328                          0
# 18329                          0
#
#                                                Key Words  \
# 1947     panties,teenager,friendship,party,female nudity
# 16315                                                  0
# 13064  live action remake of anime,based on manga,gam...
# 9324   lawyer,spin off,psychosomatic illness,criminal...
# 2348   drug abuse,narcotic abuse,overdose,prostitutio...
# ...                                                  ...
# 18259                                                  0
# 18277                                                  0
# 18327                                                  0
# 18328                                                  0
# 18329                                                  0
#
#                                              Description     Type  \
# 1947   Tells the true and untold story of prolific ra...  TV Show
# 16315  A girl in search of her true reflection in a d...  TV Show
# 13064  After their van breaks down in the middle of n...    Movie
# 9324   Drea and Eleanor agree to go after one another...    Movie
# 2348   Follows the tragedy in which terrorists detona...  TV Show
# ...                                                  ...      ...
# 18259                                                  0  TV Show
# 18277                                                  0    Movie
# 18327                                                  0    Movie
# 18328                                                  0    Movie
# 18329                                                  0    Movie
#
#       release_date_parsed  Korea
# 1947           2020-06-05      1
# 16315                 NaT      1
# 13064          2017-09-22      1
# 9324           2019-01-25      1
# 2348           2018-09-24      1
# ...                   ...    ...
# 18259                 NaT      1
# 18277                 NaT      1
# 18327                 NaT      1
# 18328                 NaT      1
# 18329                 NaT      1
#
# [1138 rows x 12 columns]

# %%
df_korea_sorted['Title_Korea'] = extract_after_slash(df_korea_sorted['Title'])

# %%
df_korea_sorted
# Out:
#                                              Title Available Globally?  \
# 1947                  Hwarang: Season 1 // 화랑: 시즌1                  No
# 16315    Love After Divorce: Season 2 // 돌싱글즈: 시즌2                  No
# 13064                               FENGSHUI // 명당                  No
# 9324                          The Roundup // 범죄도시2                  No
# 2348                 Signal: Season 1 // 시그널: 시즌 1                  No
# ...                                            ...                 ...
# 18259  Yellow Muzi & Friends: Season 1 // 내 마음은 무지                  No
# 18277              Young Adult Matters // 어른들은 몰라요                  No
# 18327                                    두근두근 내 인생                  No
# 18328                                       라디오 스타                  No
# 18329                                       선생 김봉두                  No
#
#       Release Date  Hours Viewed  Number of Ratings  Rating  \
# 1947    2020-06-05       4600000                 12      10
# 16315            0             0                 12      10
# 13064   2017-09-22       1200000                  5       9
# 9324    2019-01-25        200000                  8       9
# 2348    2018-09-24       3100000                237       9
# ...            ...           ...                ...     ...
# 18259            0             0                  0       0
# 18277            0             0                  0       0
# 18327            0             0                  0       0
# 18328            0             0                  0       0
# 18329            0             0                  0       0
#
#                            Genre  \
# 1947                 Documentary
# 16315          Drama, Reality-TV
# 13064     Comedy, Drama, Romance
# 9324         Documentary, Comedy
# 2348   Action, Adventure, Comedy
# ...                          ...
# 18259                          0
# 18277                          0
# 18327                          0
# 18328                          0
# 18329                          0
#
#                                                Key Words  \
# 1947     panties,teenager,friendship,party,female nudity
# 16315                                                  0
# 13064  live action remake of anime,based on manga,gam...
# 9324   lawyer,spin off,psychosomatic illness,criminal...
# 2348   drug abuse,narcotic abuse,overdose,prostitutio...
# ...                                                  ...
# 18259                                                  0
# 18277                                                  0
# 18327                                                  0
# 18328                                                  0
# 18329                                                  0
#
#                                              Description     Type  \
# 1947   Tells the true and untold story of prolific ra...  TV Show
# 16315  A girl in search of her true reflection in a d...  TV Show
# 13064  After their van breaks down in the middle of n...    Movie
# 9324   Drea and Eleanor agree to go after one another...    Movie
# 2348   Follows the tragedy in which terrorists detona...  TV Show
# ...                                                  ...      ...
# 18259                                                  0  TV Show
# 18277                                                  0    Movie
# 18327                                                  0    Movie
# 18328                                                  0    Movie
# 18329                                                  0    Movie
#
#       release_date_parsed  Korea    Title_Korea
# 1947           2020-06-05      1        화랑: 시즌1
# 16315                 NaT      1      돌싱글즈: 시즌2
# 13064          2017-09-22      1             명당
# 9324           2019-01-25      1          범죄도시2
# 2348           2018-09-24      1      시그널: 시즌 1
# ...                   ...    ...            ...
# 18259                 NaT      1       내 마음은 무지
# 18277                 NaT      1       어른들은 몰라요
# 18327                 NaT      1  Not Available
# 18328                 NaT      1  Not Available
# 18329                 NaT      1  Not Available
#
# [1138 rows x 13 columns]

# %%
# '시즌' 또는 '시리즈' 또는 'Series'가 포함되어 있는지 확인하고, 새로운 값을 할당하는 함수
def assign_type(row):
    if '시즌' in row['Title_Korea'] or '시리즈' in row['Title_Korea'] or 'Series' in row['Title_Korea'] or 'Series' in row['Title_Korea']:
        return 'TV Show'
    else:
        return 'Movie'

# %%
# 'Title_Korea' 열을 기반으로 'Type_New' 열에 값을 할당
df_korea_sorted['Type_New'] = df_korea_sorted.apply(assign_type, axis=1)

# %%
df_korea_movie = df_korea_sorted[df_korea_sorted['Type_New']=='Movie']

# %%
df_korea_movie_global = df_korea_movie[df_korea_movie['Available Globally?'] == 'Yes']
df_korea_movie_n = df_korea_movie[df_korea_movie['Available Globally?'] == 'No']

# %%
print(df_korea_movie_global['Title_Korea'].tolist())
# Out:
# ['길복순', '핑크퐁 시네마 콘서트: 우주대탐험', '낙원의 밤', '기억의 밤', '마녀체력 농구부: 2022', '20세기 소녀', '강철비', '연애의 참견: 2021', '염력', '아는 형님: 2020', '아는 형님: 2023', '해적: 도깨비 깃발', '런닝맨', '서울대작전', '환혼: 파트 1', '위시유', '뭉쳐야 찬다: 2023', '페르소나: 컬렉션', '미씽: 그들이 있었다', '사바하', '신비아파트: 고스트볼의 비밀', '블랙독', '보이스 2', '뭉쳐야 찬다: 2021-2022', '캐치! 티니핑', '또봇V <갤럭시웨폰 4호의 비밀>', '스마트폰을 떨어뜨렸을 뿐인데', '새콤달콤', '왕이 된 남자', '사냥의 시간', '유열의 음악앨범', '킹덤: 아신전', '악질경찰', '으라차차 와이키키', '상류사회', '진심이 닿다', '킹 오브 클론 : 황우석 박사의 몰락', '야차', '제8일의 밤', '1호가 될 순 없어: 2021', '스마트폰을 떨어뜨렸을 뿐인데', '신데렐라와 네 명의 기사', '정이', '마약왕', '미생', '캐치! 티니핑: 반짝반짝 캐치! 티니핑', '아는 형님: 2022', '최강야구: Part 1', '아는 형님: 2021', '사이버 지옥: n번방을 무너뜨려라', '환혼: 파트 2', '무법변호사', '최강야구: Part 2', '도시괴담: 컬렉션', '#살아있다', '카터', '모럴센스', '리벤져', '콜', '승리호', 'Not Available', '멜로가 체질', '인랑', '차인표']

# %% [markdown]
# - 분류기준에 적용되지 않는 제목은 일일이 제거

# %%
df_korea_sorted.to_csv('../data/netflix_korea.csv', index = False, encoding = 'utf-8-sig')

# %%
movie = pd.read_csv('../data/unique_boxoffice.csv')

# %%
movie_df = movie.copy()
ott_df = df_korea_sorted.copy()

# %%
# movieNm과 Title_Korea가 일치하는 행을 찾기
common_titles = pd.merge(movie_df, ott_df, how='inner', left_on='movieNm', right_on='Title_Korea')

# 공통된 값 추출
common_titles_list = common_titles['movieNm'].tolist()

# 공통되지 않은 값 추출
movie_only_list = movie_df[~movie_df['movieNm'].isin(common_titles_list)]['movieNm'].tolist()
ott_only_list = ott_df[~ott_df['Title_Korea'].isin(common_titles_list)]['Title_Korea'].tolist()

print("공통된 값:", common_titles_list)
# Out:
# 공통된 값: ['#살아있다', '7년의 밤', '82년생 김지영', 'B컷', 'PMC: 더 벙커', '가려진 시간', '가장 보통의 연애', '간신', '감쪽같은 그녀', '강남 1970', '강릉', '강철비', '강철비2: 정상회담', '걸캅스', '검객', '검사외전', '게이트', '결백', '경관의 피', '고백', '고산자, 대동여지도', '곡성', '곤지암', '공기살인', '공작', '공조', '공조2: 인터내셔날', '괴물', '괴물', '교섭', '국가부도의 날', '국제수사', '국제시장', '군함도', '굿바이 싱글', '궁합', '귀문', '그것만이 내 세상', '그날의 분위기', '극비수사', '극장판 공룡메카드: 타이니소어의 섬', '극장판 안녕 자두야', '극한직업', '기묘한 가족', '기방도령', '기생충', '기술자들', '기억의 밤', '기적', '꾼', '꿈의 제인', '나를 기억해', '나를 잊지 말아요', '나를 찾아줘', '나쁜 녀석들: 더 무비', '남과 여', '남매의 여름밤', '남산의 부장들', '남한산성', '내부자들', '내안의 그놈', '내일의 기억', '너의 결혼식', '늑대사냥', '다만 악에서 구하소서', '담보', '대무가', '대호', '더 박스', '더 킬러: 죽어도 되는 아이', '더 킹', '더 킹', '덕혜옹주', '데시벨', '도굴', '도어락', '독전', '독전: 익스텐디드 컷', '돈', '동감', '동네사람들', '동네사람들', '럭키', '레슬러', '롱 리브 더 킹: 목포 영웅', '루시드 드림', '리얼', '리틀 포레스트', '마녀', '마루이 비디오', '마스터', '마약왕', '말모이', '명당', '모가디슈', '목격자', '무뢰한', '물괴', '미나리', '미드나이트', '미션 파서블', '미스터 보스', '미스터 주: 사라진 VIP', '미쓰 와이프', '미쓰백', '미씽: 사라진 여자', '미씽: 사라진 여자', '미옥', '미혹', '바람 바람 바람', '반도', '반드시 잡는다', '발신제한', '밥정', '방법: 재차의', '백두산', '버닝', '번개맨과 신비의 섬', '벌새', '범죄도시', '범죄도시2', '베테랑', '변산', '변신', '보안관', '보이스', '보통사람', '봉오동 전투', '봉이 김선달', '부라더', '부산행', '불도저에 탄 소녀', '불한당: 나쁜 놈들의 세상', '뷰티 인사이드', '브로커', '블랙머니', '비밀은 없다', '비밀의 정원', '비밀의 정원', '비정규직 특수요원', '뺑반', '사냥', '사도', '사라진 시간', '사랑하기 때문에', '사바하', '사자', '살인의뢰', '살인의뢰', '살인자의 기억법', '삼진그룹 영어토익반', '상류사회', '새해전야', '생일', '서울괴담', '성난 변호사', '성난황소', '세자매', '소리도 없이', '소수의견', '순수의 시대', '스물', '스위치', '스위치', '스위치', '스파이', '시간이탈자', '시동', '시민 노무현', '신과함께-인과 연', '신과함께-죄와 벌', '신의 한 수: 귀수편', '싱크홀', '쎄시봉', '아가씨', '아빠는 딸', '아수라', '아이', '아이들은 즐겁다', '악녀', '악의 연대기', '악인전', '악질경찰', '안녕하세요', '안시성', '암살', '암수살인', '암전', '압꾸정', '앵커', '어른들은 몰라요', '어린 의뢰인', '어부바', '언니', '언니', '엑시트', '여교사', '연애 빠진 로맨스', '염력', '영웅', '영웅', '오늘의 연애', '오케이 마담', '오피스', '올레', '올빼미', '완벽한 타인', '외계+인 1부', '워킹걸', '원라인', '유열의 음악앨범', '유체이탈자', '이상한 나라의 수학자', '이웃사촌', '인랑', '인생은 아름다워', '인어공주', '인질', '인천상륙작전', '임금님의 사건수첩', '자백', '자백', '자산어보', '장르만 로맨스', '장산범', '재심', '젊은이의 양지', '정직한 후보', '조선명탐정 : 사라진 놉의 딸', '조선명탐정: 흡혈괴마의 비밀', '조작된 도시', '좋아해줘', '죄 많은 소녀', '죽지않는 인간들의 밤', '증인', '지금 만나러 갑니다', '지푸라기라도 잡고 싶은 짐승들', '차이나타운', '찬실이는 복도 많지', '창궐', '천문: 하늘에 묻는다', '청년경찰', '추억의 검정고무신', '치외법권', '침입자', '카운트', '크리스마스 캐럴', '클래식', '클로젯', '타짜: 원 아이드 잭', '탐정 : 더 비기닝', '탐정 홍길동: 사라진 마을', '탐정: 리턴즈', '택시운전사', '터널', '퇴마: 무녀굴', '특별시민', '특종: 량첸살인기', '파이프라인', '판도라', '프리즌', '한산 리덕스', '해빙', '해어화', '해적: 도깨비 깃발', '해치지않아', '헌트', '헤어질 결심', '협녀, 칼의 기억', '협상', '형', '호텔 레이크', '혼숨', '혼자 사는 사람들', '흥부: 글로 세상을 바꾼 자', '희생부활자', '히말라야', '히트맨', '힘을 내요, 미스터 리']

# %%
common_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 279 entries, 0 to 278
# Data columns (total 49 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   movieNm                       279 non-null    object
#  1   movieCd                       279 non-null    object
#  2   openDt                        279 non-null    object
#  3   salesAcc                      279 non-null    int64
#  4   audiAcc                       279 non-null    int64
#  5   scrnCnt                       279 non-null    int64
#  6   showTm                        103 non-null    float64
#  7   typeNm                        103 non-null    object
#  8   nationNm                      103 non-null    object
#  9   genreNm                       103 non-null    object
#  10  director                      103 non-null    object
#  11  actor1                        103 non-null    object
#  12  actor2                        103 non-null    object
#  13  showTypeGroupNm               103 non-null    object
#  14  showTypeNm                    103 non-null    object
#  15  audits                        103 non-null    object
#  16  commercial                    279 non-null    int64
#  17  first_until_weekday_audiAcc   263 non-null    float64
#  18  first_until_weekday_salesAcc  263 non-null    float64
#  19  1_weeks_audiAcc               274 non-null    float64
#  20  1_weeks_salesAcc              274 non-null    float64
#  21  2_weeks_audiAcc               277 non-null    float64
#  22  2_weeks_salesAcc              277 non-null    float64
#  23  3_weeks_audiAcc               278 non-null    float64
#  24  3_weeks_salesAcc              278 non-null    float64
#  25  4_weeks_audiAcc               278 non-null    float64
#  26  4_weeks_salesAcc              278 non-null    float64
#  27  5_weeks_audiAcc               278 non-null    float64
#  28  5_weeks_salesAcc              278 non-null    float64
#  29  6_weeks_audiAcc               278 non-null    float64
#  30  6_weeks_salesAcc              278 non-null    float64
#  31  7_weeks_audiAcc               278 non-null    float64
#  32  7_weeks_salesAcc              278 non-null    float64
#  33  8_weeks_audiAcc               278 non-null    float64
#  34  8_weeks_salesAcc              278 non-null    float64
#  35  Title                         279 non-null    object
#  36  Available Globally?           279 non-null    object
#  37  Release Date                  279 non-null    object
#  38  Hours Viewed                  279 non-null    float64
#  39  Number of Ratings             279 non-null    float64
#  40  Rating                        279 non-null    float64
#  41  Genre                         279 non-null    object
#  42  Key Words                     279 non-null    object
#  43  Description                   279 non-null    object
#  44  Type                          279 non-null    object
#  45  release_date_parsed           191 non-null    datetime64[ns]
#  46  Korea                         279 non-null    int64
#  47  Title_Korea                   279 non-null    object
#  48  Type_New                      279 non-null    object
# dtypes: datetime64[ns](1), float64(22), int64(5), object(21)
# memory usage: 109.0+ KB

# %%
same_movie = common_titles[['movieNm','salesAcc','audiAcc','scrnCnt','Hours Viewed','Genre']]

# %%
same_movie
# Out:
#              movieNm     salesAcc  audiAcc  scrnCnt  Hours Viewed  \
# 0              #살아있다  15965329900  1903703    34890       4600000
# 1              7년의 밤   3930732524   521564     8358        400000
# 2           82년생 김지영  30244988930  3671152    34668       3700000
# 3                 B컷     17091700     2396       82       1200000
# 4          PMC: 더 벙커  13976452874  1665200    13491     168300000
# ..               ...          ...      ...      ...           ...
# 274  흥부: 글로 세상을 바꾼 자   3300753200   404649     5994             0
# 275            희생부활자   2356707035   300737     4723        400000
# 276             히말라야  60147319815  7755848    33740       6700000
# 277              히트맨  20601798140  2404799    21387        400000
# 278     힘을 내요, 미스터 리   9777771276  1158868    11478             0
#
#                              Genre
# 0         Comedy, Fantasy, Romance
# 1                           Horror
# 2    Documentary, Biography, Drama
# 3                            Short
# 4                           Comedy
# ..                             ...
# 274            Documentary, Comedy
# 275         Documentary, Biography
# 276          Game-Show, Reality-TV
# 277  Documentary, Biography, Sport
# 278         Action, Comedy, Family
#
# [279 rows x 6 columns]

# %% [markdown]
# 가설 : 영화관에서 인기가 많은 영화는 넷플릭스에서도 인기가 많은가?

# %%
movie_by_box = same_movie.sort_values(by= 'audiAcc', ascending = False)
movie_by_ott = same_movie.sort_values(by= 'Hours Viewed', ascending = False)

# %%
movie_by_box.head(10)
# Out:
#        movieNm      salesAcc   audiAcc  scrnCnt  Hours Viewed  \
# 42        극한직업  139565890466  16252575    60881     139300000
# 170  신과함께-죄와 벌  115624855737  14401147    54620       4300000
# 32        국제시장  110818803230  14241429    37090       8000000
# 121        베테랑  105095414150  13403414    43628       1700000
# 185         암살   98319477081  12686446    42640       5500000
# 120      범죄도시2  131223480300  12686210    81645        200000
# 169  신과함께-인과 연  102587987709  12264813    44120        800000
# 253      택시운전사   95706341049  12166659    44942       1700000
# 130        부산행   93057938248  11551067    35646       2600000
# 45         기생충   87354331615  10300613    55205        200000
#
#                             Genre
# 42             Documentary, Music
# 170            Documentary, Music
# 32   Animation, Action, Adventure
# 121                 Comedy, Drama
# 185                         Drama
# 120           Documentary, Comedy
# 169          Comedy, Crime, Drama
# 253       Biography, Crime, Drama
# 130      Action, Adventure, Crime
# 45                   Crime, Drama

# %%
movie_by_ott.head(10)
# Out:
#          movieNm      salesAcc   audiAcc  scrnCnt  Hours Viewed  \
# 4      PMC: 더 벙커   13976452874   1665200    13491     168300000
# 249  타짜: 원 아이드 잭   19645339254   2224338    18057     157600000
# 42          극한직업  139565890466  16252575    60881     139300000
# 129          부라더   11665599098   1475089    13707     136200000
# 24            공작   42730172626   4966175    27450      86100000
# 88            마녀   27220439563   3186430    23689      82100000
# 115          백두산   69747400040   8242478    59601      77800000
# 266           헌트   44550232361   4346803    45747      67000000
# 11           강철비   35439102866   4445387    23819      54400000
# 254           터널   57518597917   7118946    26176      50800000
#
#                       Genre
# 4                    Comedy
# 249       Drama, Reality-TV
# 42       Documentary, Music
# 129           Drama, Family
# 24         Biography, Drama
# 88   Drama, Fantasy, Horror
# 115    Comedy, Crime, Drama
# 266    Comedy, Crime, Drama
# 11            Comedy, Crime
# 254                  Comedy

# %%
movie_by_box_title = movie_by_box['movieNm'].tolist()
movie_by_ott_title = movie_by_ott['movieNm'].tolist()

# %%
print('박스오피스 인기순:' , movie_by_box_title)
print('넷플릭스 인기순:' , movie_by_ott_title)
# Out:
# 박스오피스 인기순: ['극한직업', '신과함께-죄와 벌', '국제시장', '베테랑', '암살', '범죄도시2', '신과함께-인과 연', '택시운전사', '부산행', '기생충', '검사외전', '엑시트', '백두산', '공조', '히말라야', '마스터', '터널', '내부자들', '인천상륙작전', '공조2: 인터내셔날', '럭키', '범죄도시', '곡성', '군함도', '사도', '청년경찰', '덕혜옹주', '안시성', '더 킹', '더 킹', '완벽한 타인', '독전', '공작', '봉오동 전투', '남산의 부장들', '나쁜 녀석들: 더 무비', '판도라', '강철비', '다만 악에서 구하소서', '헌트', '아가씨', '꾼', '조선명탐정 : 사라진 놉의 딸', '남한산성', '반도', '암수살인', '국가부도의 날', '82년생 김지영', '모가디슈', '그것만이 내 세상', '돈', '악인전', '올빼미', '시동', '영웅', '영웅', '마녀', '탐정: 리턴즈', '스물', '형', '프리즌', '가장 보통의 연애', '말모이', '극비수사', '너의 결혼식', '곤지암', '살인자의 기억법', '탐정 : 더 비기닝', '지금 만나러 갑니다', '아수라', '보안관', '기술자들', '증인', '목격자', '조작된 도시', '블랙머니', '조선명탐정: 흡혈괴마의 비밀', '재심', '히트맨', '사바하', '스파이', '타짜: 원 아이드 잭', '싱크홀', '악의 연대기', '강남 1970', '신의 한 수: 귀수편', '굿바이 싱글', '명당', '뷰티 인사이드', '봉이 김선달', '천문: 하늘에 묻는다', '협상', '내안의 그놈', '#살아있다', '오늘의 연애', '헤어질 결심', '마약왕', '뺑반', '강철비2: 정상회담', '변신', '대호', '담보', '교섭', '쎄시봉', 'PMC: 더 벙커', '인질', '임금님의 사건수첩', '걸캅스', '사자', '창궐', '성난황소', '삼진그룹 영어토익반', '도굴', '외계+인 1부', '도어락', '정직한 후보', '리틀 포레스트', '부라더', '차이나타운', '탐정 홍길동: 사라진 마을', '보이스', '기억의 밤', '특별시민', '해적: 도깨비 깃발', '궁합', '장산범', '클로젯', '브로커', '유열의 음악앨범', '오케이 마담', '해치지않아', '해빙', '시간이탈자', '악녀', '생일', '바람 바람 바람', '인생은 아름다워', '힘을 내요, 미스터 리', '미씽: 사라진 여자', '미씽: 사라진 여자', '미나리', '성난 변호사', '간신', '롱 리브 더 킹: 목포 영웅', '미쓰 와이프', '염력', '고산자, 대동여지도', '발신제한', '불한당: 나쁜 놈들의 세상', '데시벨', '결백', '인랑', '살인의뢰', '살인의뢰', '좋아해줘', '유체이탈자', '레슬러', '상류사회', '자백', '자백', '물괴', '미쓰백', '기적', '경관의 피', '그날의 분위기', '인어공주', '아빠는 딸', '사냥', '나를 찾아줘', '지푸라기라도 잡고 싶은 짐승들', '특종: 량첸살인기', '압꾸정', '연애 빠진 로맨스', '미스터 주: 사라진 VIP', '국제수사', '침입자', '이상한 나라의 수학자', '버닝', '7년의 밤', '장르만 로맨스', '괴물', '괴물', '가려진 시간', '동감', '해어화', '감쪽같은 그녀', '변산', '순수의 시대', '리얼', '동네사람들', '동네사람들', '미션 파서블', '반드시 잡는다', '늑대사냥', '오피스', '원라인', '이웃사촌', '협녀, 칼의 기억', '나를 잊지 말아요', '스위치', '스위치', '스위치', '무뢰한', '극장판 공룡메카드: 타이니소어의 섬', '흥부: 글로 세상을 바꾼 자', '소리도 없이', '카운트', '보통사람', '소수의견', '자산어보', '치외법권', '사랑하기 때문에', '내일의 기억', '강릉', '희생부활자', '기방도령', '혼숨', '극장판 안녕 자두야', '악질경찰', '기묘한 가족', '미옥', '비밀은 없다', '어린 의뢰인', '언니', '언니', '검객', '사라진 시간', '남과 여', '방법: 재차의', '앵커', '새해전야', '공기살인', '마루이 비디오', '워킹걸', '비정규직 특수요원', '파이프라인', '나를 기억해', '독전: 익스텐디드 컷', '더 박스', '퇴마: 무녀굴', '벌새', '서울괴담', '미드나이트', '여교사', '암전', '죽지않는 인간들의 밤', '루시드 드림', '귀문', '게이트', '세자매', '호텔 레이크', '올레', '더 킬러: 죽어도 되는 아이', '대무가', '번개맨과 신비의 섬', '아이', '고백', '안녕하세요', '어른들은 몰라요', '어부바', '크리스마스 캐럴', '추억의 검정고무신', '찬실이는 복도 많지', '아이들은 즐겁다', '한산 리덕스', '남매의 여름밤', '꿈의 제인', '불도저에 탄 소녀', '클래식', '미혹', '죄 많은 소녀', '시민 노무현', '혼자 사는 사람들', '비밀의 정원', '비밀의 정원', '밥정', 'B컷', '젊은이의 양지', '미스터 보스']
# 넷플릭스 인기순: ['PMC: 더 벙커', '타짜: 원 아이드 잭', '극한직업', '부라더', '공작', '마녀', '백두산', '헌트', '강철비', '터널', '판도라', '올레', '엑시트', '마루이 비디오', '너의 결혼식', '동네사람들', '동네사람들', '내일의 기억', '더 킬러: 죽어도 되는 아이', '경관의 피', '성난 변호사', '반드시 잡는다', '인랑', '악질경찰', '보이스', '나쁜 녀석들: 더 무비', '간신', '강릉', '브로커', '연애 빠진 로맨스', '검사외전', '유열의 음악앨범', '순수의 시대', '대무가', '조작된 도시', '사바하', '증인', '그것만이 내 세상', '럭키', '영웅', '영웅', '살인자의 기억법', '인생은 아름다워', '걸캅스', '언니', '언니', '국제시장', '리얼', '탐정: 리턴즈', '클로젯', '크리스마스 캐럴', '히말라야', '더 킹', '더 킹', '스파이', '무뢰한', '스물', '동감', '한산 리덕스', '도굴', '다만 악에서 구하소서', '암살', '지금 만나러 갑니다', '지푸라기라도 잡고 싶은 짐승들', '마약왕', '공조2: 인터내셔날', '염력', '모가디슈', '#살아있다', '꾼', '고백', '신과함께-죄와 벌', '청년경찰', '82년생 김지영', '괴물', '리틀 포레스트', '나를 기억해', '앵커', '공조', '형', '마스터', '봉이 김선달', '탐정 : 더 비기닝', '부산행', '상류사회', '봉오동 전투', '협상', '추억의 검정고무신', '궁합', '악녀', '악인전', '해적: 도깨비 깃발', '독전', '루시드 드림', '남과 여', '담보', '미옥', '방법: 재차의', '사자', '군함도', '베테랑', '택시운전사', '버닝', '압꾸정', '가장 보통의 연애', '아빠는 딸', '국가부도의 날', '남한산성', 'B컷', '명당', '늑대사냥', '교섭', '게이트', '곤지암', '안녕하세요', '뺑반', '정직한 후보', '이상한 나라의 수학자', '스위치', '결백', '스위치', '미혹', '프리즌', '신과함께-인과 연', '오늘의 연애', '이웃사촌', '레슬러', '스위치', '발신제한', '미션 파서블', '여교사', '돈', '사라진 시간', '외계+인 1부', '미스터 주: 사라진 VIP', '오케이 마담', '헤어질 결심', '죽지않는 인간들의 밤', '인천상륙작전', '성난황소', '탐정 홍길동: 사라진 마을', '서울괴담', '원라인', '장르만 로맨스', '신의 한 수: 귀수편', '비정규직 특수요원', '기억의 밤', '반도', '공기살인', '불한당: 나쁜 놈들의 세상', '괴물', '시동', '아수라', '강철비2: 정상회담', '싱크홀', '7년의 밤', '희생부활자', '히트맨', '살인의뢰', '파이프라인', '악의 연대기', '클래식', '살인의뢰', '내안의 그놈', '보안관', '범죄도시', '덕혜옹주', '데시벨', '범죄도시2', '아가씨', '기생충', '목격자', '남산의 부장들', '임금님의 사건수첩', '검객', '자백', '자백', '세자매', '미나리', '새해전야', '카운트', '암수살인', '죄 많은 소녀', '변신', '미쓰 와이프', '미드나이트', '독전: 익스텐디드 컷', '치외법권', '내부자들', '완벽한 타인', '감쪽같은 그녀', '사랑하기 때문에', '천문: 하늘에 묻는다', '창궐', '찬실이는 복도 많지', '차이나타운', '기술자들', '기적', '꿈의 제인', '좋아해줘', '나를 잊지 말아요', '기방도령', '국제수사', '침입자', '해빙', '가려진 시간', '흥부: 글로 세상을 바꾼 자', '혼자 사는 사람들', '혼숨', '호텔 레이크', '강남 1970', '협녀, 칼의 기억', '해치지않아', '고산자, 대동여지도', '해어화', '곡성', '기묘한 가족', '특종: 량첸살인기', '특별시민', '퇴마: 무녀굴', '조선명탐정 : 사라진 놉의 딸', '굿바이 싱글', '귀문', '그날의 분위기', '극비수사', '극장판 공룡메카드: 타이니소어의 섬', '극장판 안녕 자두야', '조선명탐정: 흡혈괴마의 비밀', '더 박스', '나를 찾아줘', '불도저에 탄 소녀', '밥정', '번개맨과 신비의 섬', '벌새', '아이들은 즐겁다', '아이', '쎄시봉', '변산', '시민 노무현', '시간이탈자', '보통사람', '뷰티 인사이드', '젊은이의 양지', '블랙머니', '비밀은 없다', '소수의견', '소리도 없이', '비밀의 정원', '비밀의 정원', '생일', '사냥', '삼진그룹 영어토익반', '사도', '안시성', '암전', '바람 바람 바람', '미씽: 사라진 여자', '재심', '장산범', '남매의 여름밤', '자산어보', '인질', '인어공주', '대호', '유체이탈자', '워킹걸', '도어락', '올빼미', '오피스', '롱 리브 더 킹: 목포 영웅', '말모이', '물괴', '미스터 보스', '미쓰백', '미씽: 사라진 여자', '어부바', '어린 의뢰인', '어른들은 몰라요', '힘을 내요, 미스터 리']

# %% [markdown]
# - 박스오피스
#     - 주로 대중적인 상업 영화나 극장에서 큰 성공을 거둔 영화들이 상위에 올라가는 경향
#     - 이러한 영화들은 대중적인 관심과 많은 관객을 유치하여 매출을 올리는데 성공한 작품들입니다.
# - 넷플릭스의 경우, 사용자들의 다양한 취향과 요구를 반영하려고 하기 때문에, 박스오피스와는 다소 다른 영화들이 인기를 끌기도 합니다.
#     - 넷플릭스에서는 상업적 성공이나 극장 매출보다는 다양한 장르와 주제의 영화, 인디 영화, 혹은 시리즈를 제공하는 경향이 있습니다.
#     - 때로는 수상 경력이나 크리티컬한 호평을 받은 작품들이 넷플릭스에서 높은 인기를 끌기도 합니다. 따라서 넷플릭스의 인기순은 다양한 취향을 반영하고 있습니다.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터프레임 df에서 'audiAcc'와 'Hours Viewed' 간의 pairplot 그리기
sns.pairplot(same_movie[['audiAcc', 'Hours Viewed']])
plt.show()

# %%
correlation = same_movie['audiAcc'].corr(same_movie['Hours Viewed'])

print("상관 계수:", correlation)
# Out:
# 상관 계수: 0.21164783806087717

# %% [markdown]
# => 넷플릭스 인기 한국 영화랑 박스오피스 인기 한국 영화랑 차이가 상관성이 작다.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 'audiAcc'에 대한 분포 확인
sns.displot(same_movie['audiAcc'], kde=True)
plt.title('Distribution of audiAcc')
plt.xlabel('audiAcc')
plt.ylabel('Frequency')
plt.show()

# 'Hours Viewed'에 대한 분포 확인
sns.displot(same_movie['Hours Viewed'], kde=True)
plt.title('Distribution of Hours Viewed')
plt.xlabel('Hours Viewed')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 'Hours Viewed'가 0인 데이터를 제외한 데이터프레임 생성
filtered_df = same_movie[same_movie['Hours Viewed'] != 0]

# 'audiAcc'에 대한 분포 확인
sns.displot(filtered_df['audiAcc'], kde=True)
plt.title('Distribution of audiAcc (excluding Hours Viewed = 0)')
plt.xlabel('audiAcc')
plt.ylabel('Frequency')
plt.show()

# 'Hours Viewed'에 대한 분포 확인
sns.displot(filtered_df['Hours Viewed'], kde=True)
plt.title('Distribution of Hours Viewed (excluding Hours Viewed = 0)')
plt.xlabel('Hours Viewed')
plt.ylabel('Frequency')
plt.show()
